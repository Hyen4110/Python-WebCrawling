# %%
import pandas as pd
import numpy as np
import re
import time
from urllib import parse
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import warnings
warnings.filterwarnings(action='ignore')

import os
import sys
import urllib.request
import json
from datetime import datetime
from tqdm.notebook import tqdm

# %%
### [1] URL 생성관련 함수
def file_to_df():
    df = pd.read_excel('apple_iphone_url.xlsx')
    df['inch'] = df['inch'].astype(str)
    df['germany_inch'] = df['inch'].apply(lambda x: re.sub("\.",",",x))
    df['russia_rom'] = df['rom'].apply(lambda x: re.sub("gb","",x))
    
    return df
    
def url_maker(df):
    df['us_url'] = "https://www.apple.com/shop/buy-iphone/"+df['family_model']+"/"+df['inch']+"-inch-display-"+df['rom']+"-"+df['color']+"-unlocked"
    df['uk_url'] = "https://www.apple.com/uk/shop/buy-iphone/"+df['family_model']+"/"+df['inch']+"-inch-display-"+df['rom']+"-"+df['color']
    df['china_url'] = "https://www.apple.com.cn/shop/buy-iphone/"+df['family_model']+"/"+df['china_code']+"/A"
    
    df['japan_url'] = 0
    df['germany_url'] = 0
    df['russia_url'] = 0

    for i in range(len(df)):
        df['japan_url'][i] = "https://www.apple.com/jp/shop/buy-iphone/"+df['family_model'][i]+"/"+df['inch'][i]+\
                    parse.quote(df['japan_code_inch'][i])+"-"+df['rom'][i]+"-"+parse.quote(df['japan_code_color'][i])
        df['germany_url'][i] = "https://www.apple.com/de/shop/buy-iphone/"+df['family_model'][i]+"/"+df['germany_inch'][i]+"%22-display-"+\
                               df['rom'][i]+"-"+parse.quote(df['germany_code'][i]) 

        if df['family_model'][i] == "iphone-se":
            df['russia_url'][i] = "https://www.apple.com/ru/shop/buy-iphone/"+df['family_model'][i]+"/"+df['germany_inch'][i]+"-"+\
                                    "%D0%B4%D1%8E%D0%B9%D0%BC%D0%BE%D0%B2%D1%8B%D0%B9-%D0%B4%D0%B8%D1%81%D0%BF%D0%BB%D0%B5%D0%B9-"+\
                                   df['russia_rom'][i]+"%D0%B3%D0%B1-"+parse.quote(df['russia_code'][i])
        else: 
             df['russia_url'][i] = "https://www.apple.com/ru/shop/buy-iphone/"+df['family_model'][i]+"/"+\
                                    "%D0%B4%D0%B8%D1%81%D0%BF%D0%BB%D0%B5%D0%B9-"+\
                                    df['germany_inch'][i]+"-"+\
                                    "%D0%B4%D1%8E%D0%B9%D0%BC%D0%B0-"+\
                                   df['russia_rom'][i]+"%D0%B3%D0%B1-"+parse.quote(df['russia_code'][i])       

    df['india_url'] = "https://www.indiaistore.com/"+df['model']+"/"
    
    return df

### [2]크롤링 관련 코드
def select_no(browser):
    try:
        no_answer = browser.find_element_by_class_name('as-inlinetradeup-selector')
        no_answer.click()
    except: pass
    #print("click No")
          
def get_delivery_date(browser,post_code):
    #1. No 선택했는지 확인    
    browser.implicitly_wait(10)
    time.sleep(2)
    delivery_date_list = browser.find_elements_by_class_name("as-purchaseinfo-dudeinfo-deliverymsg")
    delivery_date_li=[]

    for i in range(len(delivery_date_list)):
        delivery_date_li.append(delivery_date_list[i].text)
        #print(delivery_date_list[i])
        #print(delivery_date_li)

    delivery_date = " / ".join(delivery_date_li)
    print(delivery_date)
    return delivery_date

def get_price_delivery(browser, url, country,i,post_code):
    time.sleep(1)
    #select_no(browser)
    delivery_date = get_delivery_date(browser,post_code)
    price = browser.find_element_by_class_name('localnav-price-content').text
    price_delivery = price+"|"+delivery_date
    return price_delivery

#네이버파파고API
def tranlator_papago(text, src_lang, dest_lang):
    
    
    client_id = "Wf_OvBKP9uonTFxvBe83" 
    client_secret = "kWuIR7oLiZ" 

    data = "source=" + src_lang + "&target=" + dest_lang + "&text=" + text
    url = "https://openapi.naver.com/v1/papago/n2mt"
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request, data=data.encode("utf-8"))
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        # print(response_body.decode('utf-8'))

        #json 형 변환
        res = json.loads(response_body.decode('utf-8'))
        
    else:
        print("Error Code:" + rescode)
    return res['message']['result']['translatedText']

def select_region(browser,post_code, delivery_text):
    
    if post_code =="101000": #russia인 경우
        a = browser.find_elements_by_xpath('//*[@data-autom="deliveryDateChecker"]')[0]
        a.click()
    else: 
        get_delivery = browser.find_element_by_xpath('//button[text()="'+delivery_text+'"]')
        get_delivery.click()
        time.sleep(2)
            
            
    if post_code =="東京都":  #japan인 경우
        a= browser.find_element_by_xpath('//*[@id="state"]')
        a.click()

        b = browser.find_element_by_xpath('//option[text()="東京都"]')
        b.click()
    
    elif post_code =="100000": # china인 경우
        a= browser.find_element_by_xpath('//*[@id="state"]')
        a.click()
        time.sleep(0.5)
        b = browser.find_element_by_xpath('//option[text()="北京"]')
        b.click()
        
        time.sleep(1)
        a= browser.find_element_by_xpath('//*[@id="city"]')
        a.click()
        time.sleep(1)
        b = browser.find_element_by_xpath('//*[@id="city"]/option[2]')
        b.click()
        
        time.sleep(1)
        a= browser.find_element_by_xpath('//*[@id="district"]')
        a.click()
        time.sleep(1)
        b = browser.find_element_by_xpath('//option[text()="东城区"]')
        b.click()
        
        try:
            input_region_code = browser.find_elements_by_xpath('//*[@id="postalCode"]')[0]
            input_region_code.send_keys(post_code)

        except:
            input_region_code = browser.find_elements_by_xpath('//*[@id="postalCode"]')
            browser.execute_script("arguments[0].click();", input_region_code)
            input_region_code.send_keys(post_code)
        
        
    else: 
        try:
            input_region_code = browser.find_elements_by_xpath('//*[@id="postalCode"]')[0]
            input_region_code.send_keys(post_code)

        except:
            time.sleep(2)
            input_region_code = browser.find_elements_by_xpath('//*[@id="postalCode"]')[0]
            input_region_code.send_keys(post_code)
#             input_region_code = browser.find_elements_by_xpath('//*[@id="postalCode"]')
#             browser.execute_script("arguments[0].click();", input_region_code)
#             input_region_code.send_keys(post_code)

    ok_button = browser.find_element_by_class_name("as-deliverydatesoverlay-geospan")
    ok_button.click()

    webdriver.ActionChains(browser).send_keys(Keys.ESCAPE).perform()        
        
    print("     > 우편번호 설정 완료*******")
    
def select_no(browser):
    try:
        no_answer = browser.find_element_by_class_name('as-inlinetradeup-selector')
        no_answer.click()
        #print("click No")
    except:
        no_answer = browser.find_element_by_class_name('as-inlinetradeup-selector')
        browser.execute_script("arguments[0].click();", no_answer)

# %%
# <1> 기본 DataFrame을 세팅한다.
#--> 실행할때마다 df가 초기화되므로 다른 cell로 뺌!!!!!!!
df = file_to_df()
df = url_maker(df)
browser = webdriver.Chrome()

# %%
# browser = webdriver.Chrome()

# %%
# %%time 
# <2> 이제부터 포문돌리면서 수집 시작!
url_list =[('usa','us_url','10001','Get delivery dates'),                               #0   usa
           ('uk','uk_url','sw1a2aa','Get delivery dates'),                              #1   uk
           ('germany','germany_url','10115','Liefertermine abrufen'),                   #2   germany/de
           ('russia','russia_url','101000','Узнайте дату доставки'), #3   russia/ru
           ('china', 'china_url','100000','查看送货日期'),                              #4   china/cn
           ('japan', 'japan_url','東京都','さらに配送オプションを表示'),                #5   japan
           ('india', 'india_url')]                                                      #6   india

# for con_num in range(2,6):
for con_num in range(6):
    country = url_list[con_num][0]        # 국가 이름
    res_col = url_list[con_num][0]+"_res" # 컬럼명1
    col_nm = url_list[con_num][1]         # url
    post_code = url_list[con_num][2]      # 지정 우편번호
    delivery_text = url_list[con_num][3]
    url = df[col_nm][0]                   #---> us_url, uk_url, china_url, japan_url, germany_url, russia_url, india_url 
    df[res_col] = 0
    print("     > "+str(con_num)+"번 국가: "+country+" 시작합니다.")
    
    
#     for i in range(44,63):
    for i in range(len(df['model'])):
        url = df[col_nm][i]
        browser.get(url)

        if i==0: #처음이면 지역선택   
            if con_num!=3: #러시아면 No 선택할필요 없음
                select_no(browser)
                
            else: pass
            
            time.sleep(4)
            select_region(browser,post_code, delivery_text)
            time.sleep(2) 
        
        elif i in [30,54]: 
            if con_num!=3: #러시아면 No 선택할필요 없음
                select_no(browser)
                
            else: pass
        else: pass
        
        print(i, end = " ")    
        price_delivery_list = get_price_delivery(browser, url,country,i,post_code)
        df[res_col][i] = price_delivery_list

    #display(df.head(2))
# Out:
#      > 0번 국가: usa 시작합니다.
#      > 우편번호 설정 완료*******
# 0 Today 9am - 11am – $9.00 / Tomorrow – Free
# 1 Today 11am - 1pm – $9.00 / Tomorrow – Free
# 2 Tomorrow – Free
# 3 Today 9am - 11am – $9.00 / Tomorrow – Free
# 4 Today 9:30am - 11:30am – $9.00 / Tomorrow – Free
# 5 Today 9:30am - 11:30am – $9.00 / Tomorrow – Free
# 6 Today 9am - 11am – $9.00 / Tomorrow – Free
# 7 Today 10am - 12pm – $9.00 / Tomorrow – Free
# 8 Today 9am - 11am – $9.00 / Tomorrow – Free
# 9 Today 10:30am - 12:30pm – $9.00 / Tomorrow – Free
# 10 Today 10am - 12pm – $9.00 / Tomorrow – Free
# 11 Today 9am - 11am – $9.00 / Tomorrow – Free
# 12 Today 10am - 12pm – $9.00 / Tomorrow – Free
# 13 Today 10am - 12pm – $9.00 / Tomorrow – Free
# 14 Today 9am - 11am – $9.00 / Tomorrow – Free
# 15 Today 11am - 1pm – $9.00 / Tomorrow – Free
# 16 Today 9am - 11am – $9.00 / Tomorrow – Free
# 17 Today 11am - 1pm – $9.00 / Tomorrow – Free
# 18 Today 9am - 11am – $9.00 / Tomorrow – Free
# 19 Today 11am - 1pm – $9.00 / Tomorrow – Free
# 20 Today 9:30am - 11:30am – $9.00 / Tomorrow – Free
# 21 Today 11am - 1pm – $9.00 / Tomorrow – Free
# 22 Today 9am - 11am – $9.00 / Tomorrow – Free
# 23 Today 10am - 12pm – $9.00 / Tomorrow – Free
# 24 Today 9:30am - 11:30am – $9.00 / Tomorrow – Free
# 25 Today 11am - 1pm – $9.00 / Tomorrow – Free
# 26 Today 9am - 11am – $9.00 / Tomorrow – Free
# 27 Today 10am - 12pm – $9.00 / Tomorrow – Free
# 28 Today 11am - 1pm – $9.00 / Tomorrow – Free
# 29 Today 10am - 12pm – $9.00 / Tomorrow – Free
# 30 Today 9:30am - 11:30am – $9.00 / Tomorrow – Free
# 31 Today 10am - 12pm – $9.00 / Tomorrow – Free
# 32 Today 9am - 11am – $9.00 / Tomorrow – Free
# 33 Today 10am - 12pm – $9.00 / Tomorrow – Free
# 34 Today 9am - 11am – $9.00 / Tomorrow – Free
# 35 Today 11am - 1pm – $9.00 / Tomorrow – Free
# 36 Today 10am - 12pm – $9.00 / Tomorrow – Free
# 37 Today 9am - 11am – $9.00 / Tomorrow – Free
# 38 Today 10am - 12pm – $9.00 / Tomorrow – Free
# 39 Today 10am - 12pm – $9.00 / Tomorrow – Free
# 40 Today 10am - 12pm – $9.00 / Tomorrow – Free
# 41 Today 10:30am - 12:30pm – $9.00 / Tomorrow – Free
# 42 Today 9:30am - 11:30am – $9.00 / Tomorrow – Free
# 43 Today 9am - 11am – $9.00 / Tomorrow – Free
# 44 Tomorrow – Free
# 45 Today 9am - 11am – $9.00 / Tomorrow – Free
# 46 Today 11am - 1pm – $9.00 / Tomorrow – Free
# 47 Today 9am - 11am – $9.00 / Tomorrow – Free
# 48 Today 10am - 12pm – $9.00 / Tomorrow – Free
# 49 Today 10am - 12pm – $9.00 / Tomorrow – Free
# 50 Today 11am - 1pm – $9.00 / Tomorrow – Free
# 51 Today 9:30am - 11:30am – $9.00 / Tomorrow – Free
# 52 Tomorrow – Free
# 53 Tomorrow – Free
# 54 Tomorrow – Free
# 55 Today 10am - 12pm – $9.00 / Tomorrow – Free
# 56 Today 11am - 1pm – $9.00 / Tomorrow – Free
# 57 Today 10am - 12pm – $9.00 / Tomorrow – Free
# 58 Today 10:30am - 12:30pm – $9.00 / Tomorrow – Free
# 59 Today 9am - 11am – $9.00 / Tomorrow – Free
# 60 Tomorrow – Free
# 61 Today 10:30am - 12:30pm – $9.00 / Tomorrow – Free
# 62 Today 9am - 11am – $9.00 / Tomorrow – Free
#      > 1번 국가: uk 시작합니다.
#      > 우편번호 설정 완료*******
# 0 Mon 22 Mar – Free
# 1 Mon 22 Mar – Free
# 2 Mon 22 Mar – Free
# 3 Mon 22 Mar – Free
# 4 Mon 22 Mar – Free
# 5 Mon 22 Mar – Free
# 6 Mon 22 Mar – Free
# 7 Mon 22 Mar – Free
# 8 Mon 22 Mar – Free
# 9 Mon 22 Mar – Free
# 10 Mon 22 Mar – Free
# 11 Mon 22 Mar – Free
# 12 Mon 22 Mar – Free
# 13 Mon 22 Mar – Free
# 14 Mon 22 Mar – Free
# 15 Mon 22 Mar – Free
# 16 Mon 22 Mar – Free
# 17 Mon 22 Mar – Free
# 18 Mon 22 Mar – Free
# 19 Mon 22 Mar – Free
# 20 Mon 22 Mar – Free
# 21 Mon 22 Mar – Free
# 22 Mon 22 Mar – Free
# 23 Mon 22 Mar – Free
# 24 Mon 22 Mar – Free
# 25 Mon 22 Mar – Free
# 26 Mon 22 Mar – Free
# 27 Mon 22 Mar – Free
# 28 Mon 22 Mar – Free
# 29 Mon 22 Mar – Free
# 30 Mon 22 Mar – Free
# 31 Mon 22 Mar – Free
# 32 Mon 22 Mar – Free
# 33 Mon 22 Mar – Free
# 34 Mon 22 Mar – Free
# 35 Mon 22 Mar – Free
# 36 Mon 22 Mar – Free
# 37 Mon 22 Mar – Free
# 38 Mon 22 Mar – Free
# 39 Mon 22 Mar – Free
# 40 Mon 22 Mar – Free
# 41 Mon 22 Mar – Free
# 42 Mon 22 Mar – Free
# 43 Mon 22 Mar – Free
# 44 Mon 22 Mar – Free
# 45 Mon 22 Mar – Free
# 46 Mon 22 Mar – Free
# 47 Mon 22 Mar – Free
# 48 Mon 22 Mar – Free
# 49 Mon 22 Mar – Free
# 50 Mon 22 Mar – Free
# 51 Mon 22 Mar – Free
# 52 Mon 22 Mar – Free
# 53 Mon 22 Mar – Free
# 54 Mon 22 Mar – Free
# 55 Mon 22 Mar – Free
# 56 Mon 22 Mar – Free
# 57 Mon 22 Mar – Free
# 58 Mon 22 Mar – Free
# 59 Mon 22 Mar – Free
# 60 Mon 22 Mar – Free
# 61 Mon 22 Mar – Free
# 62 Mon 22 Mar – Free
#      > 2번 국가: germany 시작합니다.
#      > 우편번호 설정 완료*******
# 0 Morgen – Kostenlos
# 1 Morgen – Kostenlos
# 2 Morgen – Kostenlos
# 3 Morgen – Kostenlos
# 4 Morgen – Kostenlos
# 5 Morgen – Kostenlos
# 6 Morgen – Kostenlos
# 7 Morgen – Kostenlos
# 8 Morgen – Kostenlos
# 9 Morgen – Kostenlos
# 10 Morgen – Kostenlos
# 11 Morgen – Kostenlos
# 12 Morgen – Kostenlos
# 13 Morgen – Kostenlos
# 14 Morgen – Kostenlos
# 15 Morgen – Kostenlos
# 16 Morgen – Kostenlos
# 17 Morgen – Kostenlos
# 18 Morgen – Kostenlos
# 19 Morgen – Kostenlos
# 20 Morgen – Kostenlos
# 21 Morgen – Kostenlos
# 22 Morgen – Kostenlos
# 23 Morgen – Kostenlos
# 24 Morgen – Kostenlos
# 25 Morgen – Kostenlos
# 26 Morgen – Kostenlos
# 27 Morgen – Kostenlos
# 28 Morgen – Kostenlos
# 29 Morgen – Kostenlos
# 30 Morgen – Kostenlos
# 31 Morgen – Kostenlos
# 32 Morgen – Kostenlos
# 33 Morgen – Kostenlos
# 34 Morgen – Kostenlos
# 35 Morgen – Kostenlos
# 36 Morgen – Kostenlos
# 37 Morgen – Kostenlos
# 38 Morgen – Kostenlos
# 39 Morgen – Kostenlos
# 40 Morgen – Kostenlos
# 41 Morgen – Kostenlos
# 42 Morgen – Kostenlos
# 43 Morgen – Kostenlos
# 44 Morgen – Kostenlos
# 45 Morgen – Kostenlos
# 46 Morgen – Kostenlos
# 47 Morgen – Kostenlos
# 48 Morgen – Kostenlos
# 49 Morgen – Kostenlos
# 50 Morgen – Kostenlos
# 51 Morgen – Kostenlos
# 52 Morgen – Kostenlos
# 53 Morgen – Kostenlos
# 54 Morgen – Kostenlos
# 55 Morgen – Kostenlos
# 56 Morgen – Kostenlos
# 57 Morgen – Kostenlos
# 58 Morgen – Kostenlos
# 59 Morgen – Kostenlos
# 60 Morgen – Kostenlos
# 61 Morgen – Kostenlos
# 62 Morgen – Kostenlos
#      > 3번 국가: russia 시작합니다.
#      > 우편번호 설정 완료*******
# 0 Пн 22 Мар – Бесплатно
# 1 Пн 22 Мар – Бесплатно
# 2 Пн 22 Мар – Бесплатно
# 3 Пн 22 Мар – Бесплатно
# 4 Пн 22 Мар – Бесплатно
# 5 Пн 22 Мар – Бесплатно
# 6 Пн 22 Мар – Бесплатно
# 7 Пн 22 Мар – Бесплатно
# 8 Пн 22 Мар – Бесплатно
# 9 Пн 22 Мар – Бесплатно
# 10 Пн 22 Мар – Бесплатно
# 11 Пн 22 Мар – Бесплатно
# 12 Пн 22 Мар – Бесплатно
# 13 Пн 22 Мар – Бесплатно
# 14 Пн 22 Мар – Бесплатно
# 15 Пн 22 Мар – Бесплатно
# 16 Пн 22 Мар – Бесплатно
# 17 Пн 22 Мар – Бесплатно
# 18 Пн 22 Мар – Бесплатно
# 19 Пн 22 Мар – Бесплатно
# 20 Пн 22 Мар – Бесплатно
# 21 Пн 22 Мар – Бесплатно
# 22 Пн 22 Мар – Бесплатно
# 23 Пн 22 Мар – Бесплатно
# 24 Пн 22 Мар – Бесплатно
# 25 Пн 22 Мар – Бесплатно
# 26 Пн 22 Мар – Бесплатно
# 27 Пн 22 Мар – Бесплатно
# 28 Пн 22 Мар – Бесплатно
# 29 Пн 22 Мар – Бесплатно
# 30 Пн 22 Мар – Бесплатно
# 31 Пн 22 Мар – Бесплатно
# 32 Пн 22 Мар – Бесплатно
# 33 Пн 22 Мар – Бесплатно
# 34 Пн 22 Мар – Бесплатно
# 35 Пн 22 Мар – Бесплатно
# 36 Пн 22 Мар – Бесплатно
# 37 Пн 22 Мар – Бесплатно
# 38 Пн 22 Мар – Бесплатно
# 39 Пн 22 Мар – Бесплатно
# 40 Пн 22 Мар – Бесплатно
# 41 Пн 22 Мар – Бесплатно
# 42 Пн 22 Мар – Бесплатно
# 43 Пн 22 Мар – Бесплатно
# 44 Пн 22 Мар – Бесплатно
# 45 Пн 22 Мар – Бесплатно
# 46 Пн 22 Мар – Бесплатно
# 47 Пн 22 Мар – Бесплатно
# 48 Пн 22 Мар – Бесплатно
# 49 Пн 22 Мар – Бесплатно
# 50 Пн 22 Мар – Бесплатно
# 51 Пн 22 Мар – Бесплатно
# 52 Пн 22 Мар – Бесплатно
# 53 Пн 22 Мар – Бесплатно
# 54 Пн 22 Мар – Бесплатно
# 55 Пн 22 Мар – Бесплатно
# 56 Пн 22 Мар – Бесплатно
# 57 Пн 22 Мар – Бесплатно
# 58 Пн 22 Мар – Бесплатно
# 59 Пн 22 Мар – Бесплатно
# 60 Пн 22 Мар – Бесплатно
# 61 Пн 22 Мар – Бесплатно
# 62 Пн 22 Мар – Бесплатно
#      > 4번 국가: china 시작합니다.
#      > 우편번호 설정 완료*******
# 0 明天 – 免费
# 1 明天 – 免费
# 2 明天 – 免费
# 3 明天 – 免费
# 4 明天 – 免费
# 5 明天 – 免费
# 6 明天 – 免费
# 7 明天 – 免费
# 8 明天 – 免费
# 9 明天 – 免费
# 10 明天 – 免费
# 11 明天 – 免费
# 12 明天 – 免费
# 13 明天 – 免费
# 14 明天 – 免费
# 15 明天 – 免费
# 16 明天 – 免费
# 17 明天 – 免费
# 18 明天 – 免费
# 19 明天 – 免费
# 20 明天 – 免费
# 21 明天 – 免费
# 22 明天 – 免费
# 23 明天 – 免费
# 24 明天 – 免费
# 25 明天 – 免费
# 26 明天 – 免费
# 27 明天 – 免费
# 28 明天 – 免费
# 29 明天 – 免费
# 30 明天 – 免费
# 31 明天 – 免费
# 32 明天 – 免费
# 33 明天 – 免费
# 34 明天 – 免费
# 35 明天 – 免费
# 36 明天 – 免费
# 37 明天 – 免费
# 38 明天 – 免费
# 39 明天 – 免费
# 40 明天 – 免费
# 41 明天 – 免费
# 42 明天 – 免费
# 43 明天 – 免费
# 44 明天 – 免费
# 45 明天 – 免费
# 46 明天 – 免费
# 47 明天 – 免费
# 48 明天 – 免费
# 49 明天 – 免费
# 50 明天 – 免费
# 51 明天 – 免费
# 52 明天 – 免费
# 53 明天 – 免费
# 54 明天 – 免费
# 55 明天 – 免费
# 56 明天 – 免费
# 57 明天 – 免费
# 58 明天 – 免费
# 59 明天 – 免费
# 60 明天 – 免费
# 61 明天 – 免费
# 62 明天 – 免费
#      > 5번 국가: japan 시작합니다.
#      > 우편번호 설정 완료*******
# 0 明日 – 送料無料
# 1 明日 – 送料無料
# 2 明日 – 送料無料
# 3 明日 – 送料無料
# 4 明日 – 送料無料
# 5 明日 – 送料無料
# 6 明日 – 送料無料
# 7 明日 – 送料無料
# 8 明日 – 送料無料
# 9 明日 – 送料無料
# 10 明日 – 送料無料
# 11 明日 – 送料無料
# 12 明日 – 送料無料
# 13 明日 – 送料無料
# 14 明日 – 送料無料
# 15 明日 – 送料無料
# 16 明日 – 送料無料
# 17 明日 – 送料無料
# 18 明日 – 送料無料
# 19 明日 – 送料無料
# 20 明日 – 送料無料
# 21 明日 – 送料無料
# 22 明日 – 送料無料
# 23 明日 – 送料無料
# 24 明日 – 送料無料
# 25 明日 – 送料無料
# 26 明日 – 送料無料
# 27 明日 – 送料無料
# 28 明日 – 送料無料
# 29 明日 – 送料無料
# 30 明日 – 送料無料
# 31 明日 – 送料無料
# 32 明日 – 送料無料
# 33 明日 – 送料無料
# 34 明日 – 送料無料
# 35 明日 – 送料無料
# 36 明日 – 送料無料
# 37 明日 – 送料無料
# 38 明日 – 送料無料
# 39 明日 – 送料無料
# 40 明日 – 送料無料
# 41 明日 – 送料無料
# 42 明日 – 送料無料
# 43 明日 – 送料無料
# 44 明日 – 送料無料
# 45 明日 – 送料無料
# 46 明日 – 送料無料
# 47 明日 – 送料無料
# 48 明日 – 送料無料
# 49 明日 – 送料無料
# 50 明日 – 送料無料
# 51 明日 – 送料無料
# 52 明日 – 送料無料
# 53 明日 – 送料無料
# 54 明日 – 送料無料
# 55 明日 – 送料無料
# 56 明日 – 送料無料
# 57 明日 – 送料無料
# 58 明日 – 送料無料
# 59 明日 – 送料無料
# 60 明日 – 送料無料
# 61 明日 – 送料無料
# 62 明日 – 送料無料
# Wall time: 44min 23s

# %%
# <1> result 결과만 가져와서 새로운 DataFrame 생성
df_b = df[['usa_res', 'uk_res','china_res','japan_res','germany_res','russia_res']]

# <2> "|"를 기준으로 가격과 Delivery Date 구분
df_b['usa_res'] = df_b['usa_res'].apply(lambda x: "mo. or $00.00|수집안됨 " if "|" not in str(x) else x)
df_b['us_price'] = df_b['usa_res'].apply(lambda x : str(x).split("or ")[1].split("|")[0])
df_b['us_delivery'] = df_b['usa_res'].apply(lambda x : x.split("or ")[1].split("|")[1])

df_b['uk_price'] = df_b['uk_res'].apply(lambda x : x.split(" or ")[1].replace("**","").split("|")[0])
df_b['uk_delivery'] = df_b['uk_res'].apply(lambda x : x.split(" or ")[1].replace("**","").split("|")[1])

df_b['ch_price'] = df_b['china_res'].apply(lambda x : x.replace("或\n","月或 ").split("月或 ")[1].split("|")[0])
df_b['ch_delivery'] = df_b['china_res'].apply(lambda x : x.replace("或\n","月或 ").split("月或 ")[1].split("|")[1])

df_b['ja_price'] = df_b['japan_res'].apply(lambda x : x.replace("（税別）","").split("|")[0])
df_b['ja_delivery'] = df_b['japan_res'].apply(lambda x : x.replace("（税別）","").split("|")[1])

df_b['de_price'] = df_b['germany_res'].apply(lambda x : x.split(" oder ")[1].replace("**","").split("|")[0])
df_b['de_delivery'] = df_b['germany_res'].apply(lambda x : x.split(" oder ")[1].replace("**","").split("|")[1])

df_b['ru_price'] = df_b['russia_res'].apply(lambda x : x.split("|")[0])
df_b['ru_delivery'] = df_b['russia_res'].apply(lambda x : x.split("|")[1])

df_b[['ch_del_tr', 'ja_del_tr' , 'de_del_tr', 'ru_del_tr']]=0

# <3> 번역 안되는 러시아어 수작업 번역
def russia_translator(text):
    text = text.replace('Янв' , 'Jan')
    text = text.replace('Фев' , 'Feb')
    text = text.replace('Мар' , 'Mar')
    text = text.replace('Апр' , 'Apr')
    text = text.replace('Май' , 'May')
    text = text.replace('июн' , 'Jun')
    text = text.replace('июл' , 'Jul')
    text = text.replace('авг' , 'Aug')
    text = text.replace('Сен' , 'Sep')
    text = text.replace('окт' , 'Oct')
    text = text.replace('ноя' , 'Nov')
    text = text.replace('дек' , 'Dec')
    text = text.replace('Бесплатно', 'Free')
    return text

for i in tqdm(range(len(df_b))):
    chinese_word = df_b['ch_delivery'][i]
    if chinese_word=="": pass
    else:
        chinese_translated = tranlator_papago(chinese_word, 'zh-CN', 'en')
        df_b['ch_del_tr'][i] = chinese_translated
    
    japanese_word = df_b['ja_delivery'][i]
    if japanese_word=="": pass
    else: 
        japanese_translated = tranlator_papago(japanese_word, 'ja', 'en')
        df_b['ja_del_tr'][i] = japanese_translated 

    try:
        germany_word = df_b['de_delivery'][i]
        if germany_word=="": pass
        else: 
            germany_translated =  tranlator_papago(germany_word, 'de', 'ko')
            df_b['de_del_tr'][i] = germany_translated
    except: df_b['de_del_tr'][i]=0
        
    df_b['ru_del_tr'][i] = russia_translator(df_b['ru_delivery'][i]) 
#     print(chinese_translated,'\n', japanese_translated,'\n', germany_translated,'\n', russia_translated)
# Out:
# HBox(children=(IntProgress(value=0, max=63), HTML(value='')))

# %%
price_delivery_col = [['us_price', 'us_delivery'], ['uk_price', 'uk_delivery'], ['ch_price', 'ch_del_tr'], 
                      ['ja_price', 'ja_del_tr'], ['de_price','de_del_tr'], ['ru_price', 'ru_del_tr']]
df_c = pd.DataFrame(columns = ['price', 'delivery'])

for i in price_delivery_col:
    df_c = np.vstack((df_c, df_b[i]))

df_c = pd.DataFrame(df_c,columns = ['price', 'delivery'])

# %%
today_date=datetime.today().strftime("%Y%m%d")
df_c.to_excel("translated_"+today_date+".xlsx")
